# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/OYEBANJI-OLAMIDE-001/MACHINE_LEARNING/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I am choosing Lane 2: Content Refresh Opportunity Scoring.
# This lane focuses on identifying existing web content that is losing historical search traffic or decaying over time. I chose this lane because optimizing existing content offers a higher and faster return on investment for marketing teams compared to producing new content from scratch, making it highly impactful for business operations.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The Decision: Which articles or URLs in
# our content library should be prioritized for historical updates and rewrites this month?
#
# The Unit of Analysis: A single unique URL / web page.
#
# The Action: A content editor or SEO writer will manually research, rewrite, and update the flagged web page.
#
# The Cost of a Wrong Call: If the model makes a False Positive (recommends a refresh on a healthy page), it wastes human writer hours and content budget rewriting something that didn't need it. If it makes a False Negative (misses a decaying page), the business suffers an opportunity cost of ongoing traffic and revenue loss.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
import pandas as pd
import numpy as np
import os

file_path = '../../data/raw/content_refresh_anonymized.csv'

# Check if the file exists
if os.path.exists(file_path):
    # Load the starter data if found
    df = pd.read_csv(file_path)
    print(f"Successfully loaded data from {file_path}")
else:
    # Create a dummy DataFrame if the file is not found
    print(f"Warning: File not found at {file_path}. Generating dummy data for demonstration.")
    np.random.seed(42) # for reproducibility
    num_rows = 100
    df = pd.DataFrame({
        'url': [f'example.com/page-{i}' for i in range(num_rows)],
        'content_age_days': np.random.randint(30, 1000, num_rows),
        'clicks': np.random.randint(50, 5000, num_rows),
        'impressions': np.random.randint(500, 50000, num_rows)
    })

# 1. Total number of pages we are analyzing
print(f"Total URLs analyzed: {len(df)}")

# 2. Average content age in days (proving things might be getting old!)
print(f"Average Content Age (Days): {df['content_age_days'].mean():.1f}")

# 3. Look at total impressions or average clicks
print(f"Average Clicks per page: {df['clicks'].mean():.1f}")
# Out:
# ...
# Total URLs analyzed: 100
# Average Content Age (Days): 499.6
# Average Clicks per page: 2612.7

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# This model will provide decision-support by identifying directional trends in performance decay based on observed historical metrics like traffic drops and content age. It cannot claim causal proof (e.g., it cannot prove that age is the sole reason traffic dropped), nor will it attempt to 'predict the Google algorithm' or guarantee that an update will permanently lock in a specific search rank.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
